# %%
from yahooquery import Ticker

# %%
#market = Ticker(['fb', 'aapl', 'amzn', 'nflx'], asynchronous=True)

# %%
#import pandas_datareader as pdr
#nasdaqSymbols=pdr.get_nasdaq_symbols()['NASDAQ Symbol'].to_numpy().tolist()

# %%
import bs4 as bs
import pickle
import requests

def save_sp500_tickers():
    resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class': 'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text.rstrip()
        tickers.append(ticker)
        
    with open("sp500tickers.pickle","wb") as f:
        pickle.dump(tickers,f)
        
    return tickers

# %%
market = Ticker(save_sp500_tickers(), asynchronous=True)

# %%
import pandas as pd

# %%
balanceSheets=market.balance_sheet(frequency="q")[[
    'asOfDate',
    'periodType',
    'InvestedCapital',
    'CashAndCashEquivalents',
    'CurrentDeferredLiabilities',
    'LongTermDebtAndCapitalLeaseObligation',
    'NonCurrentDeferredLiabilities',
    'OtherNonCurrentLiabilities',
    'CapitalStock',
    'CommonStock'
]]

# %%
balanceSheets
# Out:
#          asOfDate periodType  InvestedCapital  CashAndCashEquivalents  \
# symbol
# A      2020-10-31         3M     7.232000e+09            1.441000e+09
# A      2021-01-31         3M     7.303000e+09            1.329000e+09
# A      2021-04-30         3M     7.742000e+09            1.380000e+09
# A      2021-07-31         3M     7.804000e+09            1.428000e+09
# AAL    2020-09-30         3M     2.667500e+10            2.530000e+08
# ...           ...        ...              ...                     ...
# XOM    2021-06-30         3M     2.191830e+11            3.465000e+09
# XRAY   2020-09-30         3M     6.986600e+09            1.272000e+09
# XRAY   2020-12-31         3M     7.244000e+09            4.380000e+08
# XRAY   2021-03-31         3M     7.178000e+09            3.180000e+08
# XRAY   2021-06-30         3M     7.325000e+09            3.320000e+08
#
#         CurrentDeferredLiabilities  LongTermDebtAndCapitalLeaseObligation  \
# symbol
# A                     3.860000e+08                           2.284000e+09
# A                     4.190000e+08                           2.185000e+09
# A                     4.290000e+08                           2.727000e+09
# A                     4.430000e+08                           2.728000e+09
# AAL                   6.954000e+09                           3.675900e+10
# ...                            ...                                    ...
# XOM                            NaN                           4.531900e+10
# XRAY                           NaN                           2.035400e+09
# XRAY                  4.100000e+07                           2.108000e+09
# XRAY                           NaN                           2.048000e+09
# XRAY                           NaN                           2.085000e+09
#
#         NonCurrentDeferredLiabilities  OtherNonCurrentLiabilities  \
# symbol
# A                                 NaN                6.140000e+08
# A                                 NaN                6.090000e+08
# A                                 NaN                7.260000e+08
# A                                 NaN                7.280000e+08
# AAL                      7.043000e+09                1.605000e+09
# ...                               ...                         ...
# XOM                      1.851100e+10                2.054500e+10
# XRAY                     4.231000e+08                4.969000e+08
# XRAY                     3.930000e+08                5.540000e+08
# XRAY                     4.110000e+08                5.360000e+08
# XRAY                     4.150000e+08                5.500000e+08
#
#         CapitalStock   CommonStock
# symbol
# A       3.000000e+06  3.000000e+06
# A       3.000000e+06  3.000000e+06
# A       3.000000e+06  3.000000e+06
# A       3.000000e+06  3.000000e+06
# AAL     5.000000e+06  5.000000e+06
# ...              ...           ...
# XOM     1.600600e+10  1.600600e+10
# XRAY    2.600000e+06  2.600000e+06
# XRAY    3.000000e+06  3.000000e+06
# XRAY    3.000000e+06  3.000000e+06
# XRAY    3.000000e+06  3.000000e+06
#
# [1414 rows x 10 columns]

# %%
incomeStatements=market.income_statement(frequency="q")[[
    'asOfDate',
    'periodType',
    'EBIT'
]]

# %%
valuationMeasures=market.valuation_measures[['asOfDate','MarketCap','periodType']]

# %%
valuationMeasures=valuationMeasures[valuationMeasures["periodType"]=="3M"]

# %%
valuationMeasures=valuationMeasures.groupby(['symbol'])['MarketCap'].max().to_frame()

# %%
valuationMeasures=valuationMeasures[valuationMeasures['MarketCap']<1000000000000]

# %%
valuationMeasures
# Out:
#            MarketCap
# symbol
# EXPD    2.141680e+10
# EXPE    2.527840e+10
# EXR     2.247829e+10
# FAST    2.988465e+10
# FFIV    1.252805e+10
# GE      1.181963e+11
# LNT     1.395438e+10

# %%
# 500mm market cap limit

# %%
#valuationMeasures = valuationMeasures[valuationMeasures['MarketCap']>500000000]

# %%
mergedBsIs = pd.merge(balanceSheets, incomeStatements, on=['asOfDate','symbol','periodType'])

# %%
mergedBsIsSum = pd.merge(mergedBsIs, valuationMeasures, on=['symbol']).fillna(0)

# %%
mergedBsIsSum = mergedBsIsSum.groupby(['symbol'])['asOfDate',
                                  'InvestedCapital',
                                  'CashAndCashEquivalents',
                                  'CurrentDeferredLiabilities',
                                  'LongTermDebtAndCapitalLeaseObligation',
                                  'NonCurrentDeferredLiabilities',
                                  'OtherNonCurrentLiabilities',
                                  'CapitalStock',
                                  'CommonStock',
                                  'EBIT',
                                  'MarketCap'].max()
# Out:
# /Users/vincentchen/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
roic = mergedBsIsSum.EBIT / mergedBsIsSum.InvestedCapital

# %%
cash = mergedBsIsSum.CashAndCashEquivalents

# %%
debt = mergedBsIsSum.CurrentDeferredLiabilities+mergedBsIsSum.LongTermDebtAndCapitalLeaseObligation+mergedBsIsSum.NonCurrentDeferredLiabilities+mergedBsIsSum.OtherNonCurrentLiabilities

# %%
preferredequity = mergedBsIsSum.CapitalStock-mergedBsIsSum.CommonStock

# %%
networth = mergedBsIsSum.InvestedCapital+cash-debt-preferredequity

# %%
faustmannRatio = mergedBsIsSum.MarketCap/networth

# %%
#criteria: ROIC > 20%

# %%
dfRoic = roic[roic>0.001].to_frame()
dfFaustmannRatio = faustmannRatio[faustmannRatio>0].to_frame()
dfRoicToFaustmann = (roic/faustmannRatio).to_frame()

# %%
dfRoic.columns=['roic']
dfFaustmannRatio.columns=['faustmannRatio']
dfRoicToFaustmann.columns=['roicToFaustmann']

# %%
dfFaustmannRatio['faustmannRank'] = dfFaustmannRatio.rank(ascending=True)
dfFaustmannRatio.sort_values(by=['faustmannRank'])
# Out:
#         faustmannRatio  faustmannRank
# symbol
# LNT           3.301249            1.0
# EXPD          5.534895            2.0
# GE            6.830579            3.0
# FFIV          8.152731            4.0
# EXR           8.164110            5.0
# FAST          9.874654            6.0

# %%
dfRoic['roicRank']=dfRoic.rank(ascending=False)
dfRoic.sort_values(by=['roicRank'])
# Out:
#             roic  roicRank
# symbol
# EXPD    0.133350       1.0
# FAST    0.095654       2.0
# FFIV    0.045372       3.0
# EXR     0.030357       4.0
# LNT     0.022620       5.0
# GE      0.009279       6.0

# %%
result = pd.merge(
    pd.merge(
        pd.merge(mergedBsIsSum,dfRoic,on=['symbol']),
        dfFaustmannRatio,
        on=['symbol']
    ),
    dfRoicToFaustmann,
    on=['symbol']
)
#.sort_values(['roicToFaustmann'],ascending=False)

# %%
result['sumRanks']=result['faustmannRank']+result['roicRank']
result.sort_values(by=['sumRanks'],ascending=True)
# Out:
#          asOfDate  InvestedCapital  CashAndCashEquivalents  \
# symbol
# EXPD   2021-06-30     3.079454e+09            1.793393e+09
# LNT    2021-06-30     1.313000e+10            1.890000e+08
# FFIV   2021-09-30     2.785094e+09            1.026829e+09
# FAST   2021-09-30     3.329700e+09            3.339000e+08
# EXR    2021-09-30     8.575589e+09            1.091240e+08
# GE     2021-09-30     1.127280e+11            3.916200e+10
#
#         CurrentDeferredLiabilities  LongTermDebtAndCapitalLeaseObligation  \
# symbol
# EXPD                   619140000.0                           3.703330e+08
# LNT                     67000000.0                           6.769000e+09
# FFIV                   968669000.0                           7.077620e+08
# FAST                           0.0                           5.326000e+08
# EXR                            0.0                           5.643946e+09
# GE                             0.0                           7.348800e+10
#
#         NonCurrentDeferredLiabilities  OtherNonCurrentLiabilities  \
# symbol
# EXPD                     1.396100e+07                0.000000e+00
# LNT                      1.865000e+09                3.910000e+08
# FFIV                     5.235870e+08                7.523600e+07
# FAST                     1.046000e+08                0.000000e+00
# EXR                      0.000000e+00                2.874610e+08
# GE                       1.839000e+09                5.925300e+10
#
#         CapitalStock  CommonStock          EBIT     MarketCap      roic  \
# symbol
# EXPD       1693000.0    1693000.0  4.106450e+08  2.141680e+10  0.133350
# LNT        3000000.0    3000000.0  2.970000e+08  1.395438e+10  0.022620
# FFIV     386236000.0  386236000.0  1.263640e+08  1.252805e+10  0.045372
# FAST       2900000.0    2900000.0  3.185000e+08  2.988465e+10  0.095654
# EXR        1338000.0    1338000.0  2.603330e+08  2.247829e+10  0.030357
# GE       708000000.0  702000000.0  1.046000e+09  1.181963e+11  0.009279
#
#         roicRank  faustmannRatio  faustmannRank  roicToFaustmann  sumRanks
# symbol
# EXPD         1.0        5.534895            2.0         0.024093       3.0
# LNT          5.0        3.301249            1.0         0.006852       6.0
# FFIV         3.0        8.152731            4.0         0.005565       7.0
# FAST         2.0        9.874654            6.0         0.009687       8.0
# EXR          4.0        8.164110            5.0         0.003718       9.0
# GE           6.0        6.830579            3.0         0.001358       9.0

# %%
result.sort_values(by=['sumRanks'],ascending=True).to_csv('austrian_10q.csv', sep='\t')

# %%
result.sort_values(by=['sumRanks'],ascending=True).head(20)
# Out:
#          asOfDate  InvestedCapital  CashAndCashEquivalents  \
# symbol
